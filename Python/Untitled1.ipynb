# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %matplotlib notebook

print(os.getcwd())

x, y = np.loadtxt('../build/out.csv', delimiter=',', unpack=True)
plt.plot(x,y)
# Out:
# /home/pieter/GitHub/GridFinder/Python
# <img src="data:image/png;base64,..." width="640">
